# %% [markdown]
# # 1. Install required libraries

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1

# %%
import requests
import json
import time
import pandas as pd
from datetime import datetime
from dotenv import load_dotenv
import os

# %% [markdown]
# # 2. Initial config

# %%
BASE_URL = "https://api.github.com"

# For this step is recommended to have a Github Personal access token (PAT)
# Go to GitHub Settings > Developer settings > Personal access tokens
TOKEN = os.getenv("GITHUB_TOKEN")  # Replace with your (PAT)

HEADERS = {
    "Authorization": f"token {TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

response = requests.get("https://api.github.com/user", headers=HEADERS)
print(response.status_code, response.text)
# Out:
# 401 {"message":"Bad credentials","documentation_url":"https://docs.github.com/rest","status":"401"}

# %% [markdown]
# #3.1. Rate limit

# %%
def handle_rate_limit(response):
    if response.status_code in (403, 429):
        reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
        current_time = int(time.time())
        wait_time = reset_time - current_time + 1
        if wait_time > 0:
            print(f"Rate limit exceeded. Waiting {wait_time} seconds...")
            time.sleep(wait_time)
    return response

# %% [markdown]
# #3.2. API Request

# %%
def make_api_request(url, params=None):
    try:
        response = requests.get(url, headers=HEADERS, params=params)
        response = handle_rate_limit(response)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error {response.status_code}: {response.text}")
            return None
    except Exception as e:
        print(f"Request failed: {str(e)}")
        return None

# %% [markdown]
# #4.1. Search repositories

# %%
def search_repositories(query, sort="stars", order="desc", per_page=30):
    url = f"{BASE_URL}/search/repositories"
    params = {
        "q": query,
        "sort": sort,
        "order": order,
        "per_page": per_page
    }
    data = make_api_request(url, params)
    if data:
        return data.get("items", [])
    return []

# %% [markdown]
# # 4.2. Get repo function

# %%
def get_repository_commits(owner, repo, per_page=30):
    url = f"{BASE_URL}/repos/{owner}/{repo}/commits"
    params = {"per_page": per_page}

    return make_api_request(url, params)

# %% [markdown]
# #4.3. Get contents function

# %%
def get_repository_contents(owner, repo, path=""):
    url = f"{BASE_URL}/repos/{owner}/{repo}/contents/{path}"

    return make_api_request(url)

# %% [markdown]
# #4.1. Paginate repositories

# %%
def paginate_repositories(query, max_pages=3, per_page=30):
    all_repos = []
    for page in range(1, max_pages + 1):
        params = {
            "q": query,
            "sort": "stars",
            "order": "desc",
            "per_page": per_page,
            "page": page
        }
        url = f"{BASE_URL}/search/repositories"
        response = make_api_request(url, params)
        if response and "items" in response:
            all_repos.extend(response["items"])
        else:
            break  # No more pages
    return all_repos

# %% [markdown]
# #4.2 Data wrangling functions

# %%
def clean_repos_data(repos_list):

    df = pd.DataFrame(repos_list)

    df['created_at'] = pd.to_datetime(df['created_at'])
    df['description'] = df['description'].fillna('No description')
    df['owner_name'] = df['owner'].apply(lambda x: x['login'])

    clean_df = df[['name', 'full_name', 'description', 'language',
                   'stargazers_count', 'created_at', 'owner_name']]

    print(f"Cleaned {len(clean_df)} repositories")
    return clean_df

# %%
def clean_commits_data(commits_list):

    df = pd.DataFrame(commits_list)

    df['author_name'] = df['commit'].apply(lambda x: x.get('author', {}).get('name', 'Unknown'))
    df['author_email'] = df['commit'].apply(lambda x: x.get('author', {}).get('email', 'Unknown'))
    df['commit_date'] = df['commit'].apply(lambda x: x.get('author', {}).get('date', ''))
    df['message'] = df['commit'].apply(lambda x: x.get('message', ''))

    df['commit_date'] = pd.to_datetime(df['commit_date'])

    df['message_clean'] = df['message'].str.strip().str.replace('\n', ' ')

    clean_df = df[['sha', 'author_name', 'author_email', 'commit_date',
                   'message', 'message_clean']]

    print(f"Cleaned {len(clean_df)} commits")
    return clean_df

# %% [markdown]
# #5.1 Examples basic functions

# %%
repo_1 = search_repositories("tetris language:assembly", per_page=5, sort = 'name', order="asc")

# %%
repo_1
# Out:
# [{'id': 791379254,
#   'node_id': 'R_kgDOLyt9Ng',
#   'name': '-Nand2Tetris',
#   'full_name': 'pliniohavila/-Nand2Tetris',
#   'private': False,
#   'owner': {'login': 'pliniohavila',
#    'id': 76018725,
#    'node_id': 'MDQ6VXNlcjc2MDE4NzI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76018725?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pliniohavila',
#    'html_url': 'https://github.com/pliniohavila',
#    'followers_url': 'https://api.github.com/users/pliniohavila/followers',
#    'following_url': 'https://api.github.com/users/pliniohavila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pliniohavila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pliniohavila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pliniohavila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pliniohavila/orgs',
#    'repos_url': 'https://api.github.com/users/pliniohavila/repos',
#    'events_url': 'https://api.github.com/users/pliniohavila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pliniohavila/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/pliniohavila/-Nand2Tetris',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris',
#   'forks_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/forks',
#   'keys_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/teams',
#   'hooks_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/hooks',
#   'issue_events_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/events',
#   'assignees_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/tags',
#   'blobs_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/languages',
#   'stargazers_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/stargazers',
#   'contributors_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/contributors',
#   'subscribers_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/subscribers',
#   'subscription_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/subscription',
#   'commits_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/merges',
#   'archive_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/downloads',
#   'issues_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/pliniohavila/-Nand2Tetris/deployments',
#   'created_at': '2024-04-24T16:01:19Z',
#   'updated_at': '2024-04-24T16:03:17Z',
#   'pushed_at': '2024-04-24T16:03:12Z',
#   'git_url': 'git://github.com/pliniohavila/-Nand2Tetris.git',
#   'ssh_url': 'git@github.com:pliniohavila/-Nand2Tetris.git',
#   'clone_url': 'https://github.com/pliniohavila/-Nand2Tetris.git',
#   'svn_url': 'https://github.com/pliniohavila/-Nand2Tetris',
#   'homepage': None,
#   'size': 228,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Assembly',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 331514837,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMzE1MTQ4Mzc=',
#   'name': '-nand2tetris-mynand-',
#   'full_name': 'hyfzero/-nand2tetris-mynand-',
#   'private': False,
#   'owner': {'login': 'hyfzero',
#    'id': 44922276,
#    'node_id': 'MDQ6VXNlcjQ0OTIyMjc2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44922276?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hyfzero',
#    'html_url': 'https://github.com/hyfzero',
#    'followers_url': 'https://api.github.com/users/hyfzero/followers',
#    'following_url': 'https://api.github.com/users/hyfzero/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hyfzero/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hyfzero/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hyfzero/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hyfzero/orgs',
#    'repos_url': 'https://api.github.com/users/hyfzero/repos',
#    'events_url': 'https://api.github.com/users/hyfzero/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hyfzero/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/hyfzero/-nand2tetris-mynand-',
#   'description': '整理了我的作业（并制作了pdf版本）和nand2课程所需的所有资料',
#   'fork': False,
#   'url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-',
#   'forks_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/forks',
#   'keys_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/teams',
#   'hooks_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/hooks',
#   'issue_events_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/events',
#   'assignees_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/tags',
#   'blobs_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/languages',
#   'stargazers_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/stargazers',
#   'contributors_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/contributors',
#   'subscribers_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/subscribers',
#   'subscription_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/subscription',
#   'commits_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/merges',
#   'archive_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/downloads',
#   'issues_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/hyfzero/-nand2tetris-mynand-/deployments',
#   'created_at': '2021-01-21T04:33:53Z',
#   'updated_at': '2023-11-22T09:30:25Z',
#   'pushed_at': '2021-01-24T11:16:19Z',
#   'git_url': 'git://github.com/hyfzero/-nand2tetris-mynand-.git',
#   'ssh_url': 'git@github.com:hyfzero/-nand2tetris-mynand-.git',
#   'clone_url': 'https://github.com/hyfzero/-nand2tetris-mynand-.git',
#   'svn_url': 'https://github.com/hyfzero/-nand2tetris-mynand-',
#   'homepage': None,
#   'size': 3524,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Assembly',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 845444206,
#   'node_id': 'R_kgDOMmR0bg',
#   'name': '-nand2tetris-Part1',
#   'full_name': 'VEERESH069/-nand2tetris-Part1',
#   'private': False,
#   'owner': {'login': 'VEERESH069',
#    'id': 116574954,
#    'node_id': 'U_kgDOBvLK6g',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116574954?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VEERESH069',
#    'html_url': 'https://github.com/VEERESH069',
#    'followers_url': 'https://api.github.com/users/VEERESH069/followers',
#    'following_url': 'https://api.github.com/users/VEERESH069/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/VEERESH069/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/VEERESH069/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/VEERESH069/subscriptions',
#    'organizations_url': 'https://api.github.com/users/VEERESH069/orgs',
#    'repos_url': 'https://api.github.com/users/VEERESH069/repos',
#    'events_url': 'https://api.github.com/users/VEERESH069/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/VEERESH069/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/VEERESH069/-nand2tetris-Part1',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1',
#   'forks_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/forks',
#   'keys_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/teams',
#   'hooks_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/hooks',
#   'issue_events_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/events',
#   'assignees_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/tags',
#   'blobs_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/languages',
#   'stargazers_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/stargazers',
#   'contributors_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/contributors',
#   'subscribers_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/subscribers',
#   'subscription_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/subscription',
#   'commits_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/merges',
#   'archive_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/downloads',
#   'issues_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/VEERESH069/-nand2tetris-Part1/deployments',
#   'created_at': '2024-08-21T09:07:13Z',
#   'updated_at': '2024-11-20T07:06:38Z',
#   'pushed_at': '2024-11-20T07:06:34Z',
#   'git_url': 'git://github.com/VEERESH069/-nand2tetris-Part1.git',
#   'ssh_url': 'git@github.com:VEERESH069/-nand2tetris-Part1.git',
#   'clone_url': 'https://github.com/VEERESH069/-nand2tetris-Part1.git',
#   'svn_url': 'https://github.com/VEERESH069/-nand2tetris-Part1',
#   'homepage': None,
#   'size': 2467,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Assembly',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 570004501,
#   'node_id': 'R_kgDOIfmUFQ',
#   'name': '-nand2tetris-Part1',
#   'full_name': 'Saksham091/-nand2tetris-Part1',
#   'private': False,
#   'owner': {'login': 'Saksham091',
#    'id': 115336477,
#    'node_id': 'U_kgDOBt_lHQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115336477?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Saksham091',
#    'html_url': 'https://github.com/Saksham091',
#    'followers_url': 'https://api.github.com/users/Saksham091/followers',
#    'following_url': 'https://api.github.com/users/Saksham091/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Saksham091/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Saksham091/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Saksham091/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Saksham091/orgs',
#    'repos_url': 'https://api.github.com/users/Saksham091/repos',
#    'events_url': 'https://api.github.com/users/Saksham091/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Saksham091/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Saksham091/-nand2tetris-Part1',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1',
#   'forks_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/forks',
#   'keys_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/teams',
#   'hooks_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/events',
#   'assignees_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/tags',
#   'blobs_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/languages',
#   'stargazers_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/subscription',
#   'commits_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/merges',
#   'archive_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/downloads',
#   'issues_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Saksham091/-nand2tetris-Part1/deployments',
#   'created_at': '2022-11-24T05:42:16Z',
#   'updated_at': '2022-11-24T05:54:02Z',
#   'pushed_at': '2022-12-13T11:23:19Z',
#   'git_url': 'git://github.com/Saksham091/-nand2tetris-Part1.git',
#   'ssh_url': 'git@github.com:Saksham091/-nand2tetris-Part1.git',
#   'clone_url': 'https://github.com/Saksham091/-nand2tetris-Part1.git',
#   'svn_url': 'https://github.com/Saksham091/-nand2tetris-Part1',
#   'homepage': None,
#   'size': 972,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Assembly',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 848173783,
#   'node_id': 'R_kgDOMo4a1w',
#   'name': '-nand2tetris-Part1-',
#   'full_name': 'pawin46/-nand2tetris-Part1-',
#   'private': False,
#   'owner': {'login': 'pawin46',
#    'id': 179121483,
#    'node_id': 'U_kgDOCq0tSw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/179121483?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pawin46',
#    'html_url': 'https://github.com/pawin46',
#    'followers_url': 'https://api.github.com/users/pawin46/followers',
#    'following_url': 'https://api.github.com/users/pawin46/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pawin46/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pawin46/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pawin46/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pawin46/orgs',
#    'repos_url': 'https://api.github.com/users/pawin46/repos',
#    'events_url': 'https://api.github.com/users/pawin46/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pawin46/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/pawin46/-nand2tetris-Part1-',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-',
#   'forks_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/forks',
#   'keys_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/teams',
#   'hooks_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/hooks',
#   'issue_events_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/events',
#   'assignees_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/tags',
#   'blobs_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/languages',
#   'stargazers_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/stargazers',
#   'contributors_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/contributors',
#   'subscribers_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/subscribers',
#   'subscription_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/subscription',
#   'commits_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/merges',
#   'archive_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/downloads',
#   'issues_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/pawin46/-nand2tetris-Part1-/deployments',
#   'created_at': '2024-08-27T09:16:51Z',
#   'updated_at': '2024-10-22T09:00:30Z',
#   'pushed_at': '2024-10-22T09:00:27Z',
#   'git_url': 'git://github.com/pawin46/-nand2tetris-Part1-.git',
#   'ssh_url': 'git@github.com:pawin46/-nand2tetris-Part1-.git',
#   'clone_url': 'https://github.com/pawin46/-nand2tetris-Part1-.git',
#   'svn_url': 'https://github.com/pawin46/-nand2tetris-Part1-',
#   'homepage': None,
#   'size': 1715,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Assembly',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0}]

# %%
comm_1 = get_repository_commits("kirjavascript", 'TetrisGYM', per_page=15)

# %%
comm_1
# Out:
# [{'sha': 'aad48e307c78d75fc6b4d05888c1529da4deeb9f',
#   'node_id': 'C_kwDOEXsaitoAKGFhZDQ4ZTMwN2M3OGQ3NWZjNmI0ZDA1ODg4YzE1MjlkYTRkZWViOWY',
#   'commit': {'author': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-06-20T21:06:07Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-06-20T21:06:07Z'},
#    'message': 'Add marathon modes 3 & 4 (#140)',
#    'tree': {'sha': 'fe2d9594b2c18e95273f84ea99fa5a89927f9d29',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/fe2d9594b2c18e95273f84ea99fa5a89927f9d29'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/aad48e307c78d75fc6b4d05888c1529da4deeb9f',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nZCN7Jr1sgjAMqd8GSTxE\n=dq8d\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree fe2d9594b2c18e95273f84ea99fa5a89927f9d29\nparent d4ffde98d5629ef4790ffa47699f7cb439631e8d\nauthor zohassadar <zohassadar@gmail.com> 1750453567 +0000\ncommitter GitHub <noreply@github.com> 1750453567 +0100\n\nAdd marathon modes 3 & 4 (#140)\n\n',
#     'verified_at': '2025-06-20T21:06:08Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/aad48e307c78d75fc6b4d05888c1529da4deeb9f',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/aad48e307c78d75fc6b4d05888c1529da4deeb9f',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/aad48e307c78d75fc6b4d05888c1529da4deeb9f/comments',
#   'author': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'd4ffde98d5629ef4790ffa47699f7cb439631e8d',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d4ffde98d5629ef4790ffa47699f7cb439631e8d',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/d4ffde98d5629ef4790ffa47699f7cb439631e8d'}]},
#  {'sha': 'd4ffde98d5629ef4790ffa47699f7cb439631e8d',
#   'node_id': 'C_kwDOEXsaitoAKGQ0ZmZkZTk4ZDU2MjllZjQ3OTBmZmE0NzY5OWY3Y2I0Mzk2MzFlOGQ',
#   'commit': {'author': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-03-26T22:22:44Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-03-26T22:22:44Z'},
#    'message': "Clean unused init bytes (#136)\n\nThese bytes are remnants from the vanilla rom and aren't used by\nanything.  They appear to be either an incorrect version of the Famicom\nDisk System Interupt/Reset vector controls, or the correct version of\nthe same controls for an internal development platform.  Either way they\ncan be cleaned up.\n\nfrom: https://www.nesdev.org/wiki/FDS_BIOS#Interrupt/Reset_vector_controls\n> Interrupt/Reset vector controls > The FDS BIOS uses 4 bytes at the\n> lower end of the stack page to control the behaviour of interrupt/reset\n> vectors:\n>\n> [$0100]:\tPC action on NMI. $C0 (NMI #3) on reset.\n> [$0101]:\tPC action on IRQ. $80 (BIOS acknowledge and delay) on reset.\n> [$0102]:\tRESET flag. $35 on reset after the boot files have loaded.\n> [$0103]:\tRESET type. $AC = first boot of the game, $53 = the game was soft-reset by the user.",
#    'tree': {'sha': '6f5a09f73b4dfe2d9f576589b2f2a8f1e6fcc258',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/6f5a09f73b4dfe2d9f576589b2f2a8f1e6fcc258'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/d4ffde98d5629ef4790ffa47699f7cb439631e8d',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n2WtpHWfygwRWHphB9zyH\n=gi4Y\n-----END PGP SIGNATURE-----\n',
#     'payload': "tree 6f5a09f73b4dfe2d9f576589b2f2a8f1e6fcc258\nparent df937b12806b35332880d37057188d052d859260\nauthor zohassadar <zohassadar@gmail.com> 1743027764 +0000\ncommitter GitHub <noreply@github.com> 1743027764 +0000\n\nClean unused init bytes (#136)\n\nThese bytes are remnants from the vanilla rom and aren't used by\nanything.  They appear to be either an incorrect version of the Famicom\nDisk System Interupt/Reset vector controls, or the correct version of\nthe same controls for an internal development platform.  Either way they\ncan be cleaned up.\n\nfrom: https://www.nesdev.org/wiki/FDS_BIOS#Interrupt/Reset_vector_controls\n> Interrupt/Reset vector controls > The FDS BIOS uses 4 bytes at the\n> lower end of the stack page to control the behaviour of interrupt/reset\n> vectors:\n>\n> [$0100]:\tPC action on NMI. $C0 (NMI #3) on reset.\n> [$0101]:\tPC action on IRQ. $80 (BIOS acknowledge and delay) on reset.\n> [$0102]:\tRESET flag. $35 on reset after the boot files have loaded.\n> [$0103]:\tRESET type. $AC = first boot of the game, $53 = the game was soft-reset by the user.",
#     'verified_at': '2025-03-26T22:22:47Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d4ffde98d5629ef4790ffa47699f7cb439631e8d',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/d4ffde98d5629ef4790ffa47699f7cb439631e8d',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d4ffde98d5629ef4790ffa47699f7cb439631e8d/comments',
#   'author': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'df937b12806b35332880d37057188d052d859260',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/df937b12806b35332880d37057188d052d859260',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/df937b12806b35332880d37057188d052d859260'}]},
#  {'sha': 'df937b12806b35332880d37057188d052d859260',
#   'node_id': 'C_kwDOEXsaitoAKGRmOTM3YjEyODA2YjM1MzMyODgwZDM3MDU3MTg4ZDA1MmQ4NTkyNjA',
#   'commit': {'author': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-02-01T19:49:33Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-02-01T19:49:33Z'},
#    'message': 'Add option to send additional build args to ca65 (#133)',
#    'tree': {'sha': '8e7912eb1112a5c103804b920493c1c71cdd742c',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/8e7912eb1112a5c103804b920493c1c71cdd742c'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/df937b12806b35332880d37057188d052d859260',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\ndF6hVv0JJdgfhb0NFsyR\n=jSUU\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 8e7912eb1112a5c103804b920493c1c71cdd742c\nparent d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2\nauthor zohassadar <zohassadar@gmail.com> 1738439373 +0000\ncommitter GitHub <noreply@github.com> 1738439373 +0000\n\nAdd option to send additional build args to ca65 (#133)\n\n',
#     'verified_at': '2025-02-01T19:49:36Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/df937b12806b35332880d37057188d052d859260',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/df937b12806b35332880d37057188d052d859260',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/df937b12806b35332880d37057188d052d859260/comments',
#   'author': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'd28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2'}]},
#  {'sha': 'd28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2',
#   'node_id': 'C_kwDOEXsaitoAKGQyOGJkNzQ0YjVmNzg0YTNiYWNmY2IwYWNmN2FjNWY0ZmNjODVkZTI',
#   'commit': {'author': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-01-30T22:47:24Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-01-30T22:47:24Z'},
#    'message': "remove unneeded legacy tables (#132)\n\norientationToSpriteTable is used to map the spawnId to the arbitrary sprite ID\r\nfor the next piece.  Reordering the sprites to match the game's piece ID order\r\nand reusing tetriminoTypeFromOrientation, this table can be removed.\r\n\r\nspawnOrientationFromOrientation may have been created in development when the\r\nRNG produced the orientation ID instead of the piece ID, but random spawn\r\norientations weren't desired.  As it's currently being used to convert the spawn\r\nID to the same spawn ID, it can be removed.\r\n\r\nReduces PRG usage by 38 bytes",
#    'tree': {'sha': 'a96673b14ccccef4f92c8531daf69a8480fad29d',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/a96673b14ccccef4f92c8531daf69a8480fad29d'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nLirHsh+4xrKVWrA5z+Ht\n=4hZS\n-----END PGP SIGNATURE-----\n',
#     'payload': "tree a96673b14ccccef4f92c8531daf69a8480fad29d\nparent 961aa7aed01dc5a2d73f33d07b7ba488fa4202a5\nauthor zohassadar <zohassadar@gmail.com> 1738277244 +0000\ncommitter GitHub <noreply@github.com> 1738277244 +0000\n\nremove unneeded legacy tables (#132)\n\norientationToSpriteTable is used to map the spawnId to the arbitrary sprite ID\r\nfor the next piece.  Reordering the sprites to match the game's piece ID order\r\nand reusing tetriminoTypeFromOrientation, this table can be removed.\r\n\r\nspawnOrientationFromOrientation may have been created in development when the\r\nRNG produced the orientation ID instead of the piece ID, but random spawn\r\norientations weren't desired.  As it's currently being used to convert the spawn\r\nID to the same spawn ID, it can be removed.\r\n\r\nReduces PRG usage by 38 bytes",
#     'verified_at': '2025-01-30T22:47:26Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2/comments',
#   'author': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '961aa7aed01dc5a2d73f33d07b7ba488fa4202a5',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/961aa7aed01dc5a2d73f33d07b7ba488fa4202a5',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/961aa7aed01dc5a2d73f33d07b7ba488fa4202a5'}]},
#  {'sha': '961aa7aed01dc5a2d73f33d07b7ba488fa4202a5',
#   'node_id': 'C_kwDOEXsaitoAKDk2MWFhN2FlZDAxZGM1YTJkNzNmMzNkMDdiN2JhNDg4ZmE0MjAyYTU',
#   'commit': {'author': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-01-30T20:05:48Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-01-30T20:05:48Z'},
#    'message': 'add harddrop.rs (#131)\n\nPut together to measure cycle count in the routines used by harddrop, mainly\r\nisPositionValid.  Not an exhaustive test but is a starting point for further\r\ntesting.  Maximum cycles measured in playerControlsActiveTetrimino at the time\r\nof this commit is 21,875.',
#    'tree': {'sha': '0bd5659f549ee4d6d7fb2029645090c2b131bccf',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/0bd5659f549ee4d6d7fb2029645090c2b131bccf'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/961aa7aed01dc5a2d73f33d07b7ba488fa4202a5',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nPPKbPPEBvBLw95v60Ze/\n=S9M/\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 0bd5659f549ee4d6d7fb2029645090c2b131bccf\nparent a222aa463090986c3ff7f82b9213bec791055d34\nauthor zohassadar <zohassadar@gmail.com> 1738267548 +0000\ncommitter GitHub <noreply@github.com> 1738267548 +0000\n\nadd harddrop.rs (#131)\n\nPut together to measure cycle count in the routines used by harddrop, mainly\r\nisPositionValid.  Not an exhaustive test but is a starting point for further\r\ntesting.  Maximum cycles measured in playerControlsActiveTetrimino at the time\r\nof this commit is 21,875.',
#     'verified_at': '2025-01-30T20:05:51Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/961aa7aed01dc5a2d73f33d07b7ba488fa4202a5',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/961aa7aed01dc5a2d73f33d07b7ba488fa4202a5',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/961aa7aed01dc5a2d73f33d07b7ba488fa4202a5/comments',
#   'author': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'a222aa463090986c3ff7f82b9213bec791055d34',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/a222aa463090986c3ff7f82b9213bec791055d34',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/a222aa463090986c3ff7f82b9213bec791055d34'}]},
#  {'sha': 'a222aa463090986c3ff7f82b9213bec791055d34',
#   'node_id': 'C_kwDOEXsaitoAKGEyMjJhYTQ2MzA5MDk4NmMzZmY3ZjgyYjkyMTNiZWM3OTEwNTVkMzQ',
#   'commit': {'author': {'name': 'Kirjava',
#     'email': 'kirjavascript@users.noreply.github.com',
#     'date': '2025-01-05T19:39:31Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-01-05T19:39:31Z'},
#    'message': 'Merge pull request #129 from zohassadar/clear_crash_state\n\nClear crashState at game init',
#    'tree': {'sha': '1bdec7155ba6f6f5cf6b3c32fa7fb10cbc0abe2c',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/1bdec7155ba6f6f5cf6b3c32fa7fb10cbc0abe2c'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/a222aa463090986c3ff7f82b9213bec791055d34',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nlmLpP72L6qNAr8Z4JnaE\n=XSRV\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 1bdec7155ba6f6f5cf6b3c32fa7fb10cbc0abe2c\nparent 9ad2faacc6cfd919782330659468028aea04533b\nparent d216a5e218f023b9f03d4affb4170f4ce0efefcb\nauthor Kirjava <kirjavascript@users.noreply.github.com> 1736105971 +0000\ncommitter GitHub <noreply@github.com> 1736105971 +0000\n\nMerge pull request #129 from zohassadar/clear_crash_state\n\nClear crashState at game init',
#     'verified_at': '2025-01-05T19:39:34Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/a222aa463090986c3ff7f82b9213bec791055d34',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/a222aa463090986c3ff7f82b9213bec791055d34',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/a222aa463090986c3ff7f82b9213bec791055d34/comments',
#   'author': {'login': 'kirjavascript',
#    'id': 4498266,
#    'node_id': 'MDQ6VXNlcjQ0OTgyNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4498266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirjavascript',
#    'html_url': 'https://github.com/kirjavascript',
#    'followers_url': 'https://api.github.com/users/kirjavascript/followers',
#    'following_url': 'https://api.github.com/users/kirjavascript/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirjavascript/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirjavascript/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirjavascript/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirjavascript/orgs',
#    'repos_url': 'https://api.github.com/users/kirjavascript/repos',
#    'events_url': 'https://api.github.com/users/kirjavascript/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirjavascript/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '9ad2faacc6cfd919782330659468028aea04533b',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/9ad2faacc6cfd919782330659468028aea04533b',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/9ad2faacc6cfd919782330659468028aea04533b'},
#    {'sha': 'd216a5e218f023b9f03d4affb4170f4ce0efefcb',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d216a5e218f023b9f03d4affb4170f4ce0efefcb',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/d216a5e218f023b9f03d4affb4170f4ce0efefcb'}]},
#  {'sha': 'd216a5e218f023b9f03d4affb4170f4ce0efefcb',
#   'node_id': 'C_kwDOEXsaitoAKGQyMTZhNWUyMThmMDIzYjlmMDNkNGFmZmI0MTcwZjRjZTBlZmVmY2I',
#   'commit': {'author': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-01-05T19:18:26Z'},
#    'committer': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-01-05T19:18:26Z'},
#    'message': 'Clear crashState at game init',
#    'tree': {'sha': '1bdec7155ba6f6f5cf6b3c32fa7fb10cbc0abe2c',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/1bdec7155ba6f6f5cf6b3c32fa7fb10cbc0abe2c'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/d216a5e218f023b9f03d4affb4170f4ce0efefcb',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None,
#     'verified_at': None}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d216a5e218f023b9f03d4affb4170f4ce0efefcb',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/d216a5e218f023b9f03d4affb4170f4ce0efefcb',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/d216a5e218f023b9f03d4affb4170f4ce0efefcb/comments',
#   'author': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '9ad2faacc6cfd919782330659468028aea04533b',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/9ad2faacc6cfd919782330659468028aea04533b',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/9ad2faacc6cfd919782330659468028aea04533b'}]},
#  {'sha': '9ad2faacc6cfd919782330659468028aea04533b',
#   'node_id': 'C_kwDOEXsaitoAKDlhZDJmYWFjYzZjZmQ5MTk3ODIzMzA2NTk0NjgwMjhhZWEwNDUzM2I',
#   'commit': {'author': {'name': 'Kirjava',
#     'email': 'kirjavascript@users.noreply.github.com',
#     'date': '2025-01-05T02:25:56Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-01-05T02:25:56Z'},
#    'message': 'Merge pull request #127 from zohassadar/floor-sec2\n\nsec in floor and adjust tspin constant',
#    'tree': {'sha': 'd0b3f6f721181460693c3546254ced313a7649a0',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/d0b3f6f721181460693c3546254ced313a7649a0'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/9ad2faacc6cfd919782330659468028aea04533b',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nLlv7Z9ZyOHLW35DM4Ou9\n=9NVZ\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree d0b3f6f721181460693c3546254ced313a7649a0\nparent 810a07f5cabc7cbbc646d24e104ab762ef7aa133\nparent 0983e24379a6195421f71da7f6a09adb9f325316\nauthor Kirjava <kirjavascript@users.noreply.github.com> 1736043956 +0000\ncommitter GitHub <noreply@github.com> 1736043956 +0000\n\nMerge pull request #127 from zohassadar/floor-sec2\n\nsec in floor and adjust tspin constant',
#     'verified_at': '2025-01-05T02:25:58Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/9ad2faacc6cfd919782330659468028aea04533b',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/9ad2faacc6cfd919782330659468028aea04533b',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/9ad2faacc6cfd919782330659468028aea04533b/comments',
#   'author': {'login': 'kirjavascript',
#    'id': 4498266,
#    'node_id': 'MDQ6VXNlcjQ0OTgyNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4498266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirjavascript',
#    'html_url': 'https://github.com/kirjavascript',
#    'followers_url': 'https://api.github.com/users/kirjavascript/followers',
#    'following_url': 'https://api.github.com/users/kirjavascript/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirjavascript/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirjavascript/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirjavascript/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirjavascript/orgs',
#    'repos_url': 'https://api.github.com/users/kirjavascript/repos',
#    'events_url': 'https://api.github.com/users/kirjavascript/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirjavascript/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/810a07f5cabc7cbbc646d24e104ab762ef7aa133'},
#    {'sha': '0983e24379a6195421f71da7f6a09adb9f325316',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/0983e24379a6195421f71da7f6a09adb9f325316',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/0983e24379a6195421f71da7f6a09adb9f325316'}]},
#  {'sha': '0983e24379a6195421f71da7f6a09adb9f325316',
#   'node_id': 'C_kwDOEXsaitoAKDA5ODNlMjQzNzlhNjE5NTQyMWY3MWRhN2Y2YTA5YWRiOWYzMjUzMTY',
#   'commit': {'author': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-01-05T02:12:46Z'},
#    'committer': {'name': 'zohassadar',
#     'email': 'zohassadar@gmail.com',
#     'date': '2025-01-05T02:12:46Z'},
#    'message': 'sec in floor and adjust tspin constant',
#    'tree': {'sha': 'd0b3f6f721181460693c3546254ced313a7649a0',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/d0b3f6f721181460693c3546254ced313a7649a0'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/0983e24379a6195421f71da7f6a09adb9f325316',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None,
#     'verified_at': None}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/0983e24379a6195421f71da7f6a09adb9f325316',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/0983e24379a6195421f71da7f6a09adb9f325316',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/0983e24379a6195421f71da7f6a09adb9f325316/comments',
#   'author': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'zohassadar',
#    'id': 23087388,
#    'node_id': 'MDQ6VXNlcjIzMDg3Mzg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23087388?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zohassadar',
#    'html_url': 'https://github.com/zohassadar',
#    'followers_url': 'https://api.github.com/users/zohassadar/followers',
#    'following_url': 'https://api.github.com/users/zohassadar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zohassadar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zohassadar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zohassadar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zohassadar/orgs',
#    'repos_url': 'https://api.github.com/users/zohassadar/repos',
#    'events_url': 'https://api.github.com/users/zohassadar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zohassadar/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/810a07f5cabc7cbbc646d24e104ab762ef7aa133'}]},
#  {'sha': '810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#   'node_id': 'C_kwDOEXsaitoAKDgxMGEwN2Y1Y2FiYzdjYmJjNjQ2ZDI0ZTEwNGFiNzYyZWY3YWExMzM',
#   'commit': {'author': {'name': 'kirjavascript',
#     'email': 'snkenjoi@gmail.com',
#     'date': '2025-01-05T01:15:54Z'},
#    'committer': {'name': 'kirjavascript',
#     'email': 'snkenjoi@gmail.com',
#     'date': '2025-01-05T01:15:54Z'},
#    'message': 'revert sec in floor code',
#    'tree': {'sha': '19106d86f6214d66a5e9d79bab562e287556b99b',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/19106d86f6214d66a5e9d79bab562e287556b99b'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None,
#     'verified_at': None}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/810a07f5cabc7cbbc646d24e104ab762ef7aa133',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/810a07f5cabc7cbbc646d24e104ab762ef7aa133/comments',
#   'author': {'login': 'kirjavascript',
#    'id': 4498266,
#    'node_id': 'MDQ6VXNlcjQ0OTgyNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4498266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirjavascript',
#    'html_url': 'https://github.com/kirjavascript',
#    'followers_url': 'https://api.github.com/users/kirjavascript/followers',
#    'following_url': 'https://api.github.com/users/kirjavascript/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirjavascript/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirjavascript/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirjavascript/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirjavascript/orgs',
#    'repos_url': 'https://api.github.com/users/kirjavascript/repos',
#    'events_url': 'https://api.github.com/users/kirjavascript/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirjavascript/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'kirjavascript',
#    'id': 4498266,
#    'node_id': 'MDQ6VXNlcjQ0OTgyNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4498266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirjavascript',
#    'html_url': 'https://github.com/kirjavascript',
#    'followers_url': 'https://api.github.com/users/kirjavascript/followers',
#    'following_url': 'https://api.github.com/users/kirjavascript/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirjavascript/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirjavascript/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirjavascript/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirjavascript/orgs',
#    'repos_url': 'https://api.github.com/users/kirjavascript/repos',
#    'events_url': 'https://api.github.com/users/kirjavascript/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirjavascript/received_events',
# ...
#    {'sha': 'bd5f80153c008b56b5d137612d5791648573b569',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/bd5f80153c008b56b5d137612d5791648573b569',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/bd5f80153c008b56b5d137612d5791648573b569'}]},
#  {'sha': '3e93562dd3308f087c262bcda0c76666dda40bab',
#   'node_id': 'C_kwDOEXsaitoAKDNlOTM1NjJkZDMzMDhmMDg3YzI2MmJjZGEwYzc2NjY2ZGRhNDBiYWI',
#   'commit': {'author': {'name': 'Kirjava',
#     'email': 'kirjavascript@users.noreply.github.com',
#     'date': '2025-01-05T01:05:11Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-01-05T01:05:11Z'},
#    'message': 'Merge pull request #120 from zohassadar/optimized_crunch\n\noptimized crunch with crash mode accommodated',
#    'tree': {'sha': '893ea434dc2a8307b658c5a4b45c49a8ea9e2853',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/893ea434dc2a8307b658c5a4b45c49a8ea9e2853'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/3e93562dd3308f087c262bcda0c76666dda40bab',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\npH9eoYL64qfbvZ91aEZ9\n=kd+i\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 893ea434dc2a8307b658c5a4b45c49a8ea9e2853\nparent 303a93fde5082e629be72e452992fd3b1ed3b464\nparent 2f04da63cd29ea5aae8ebc78b3e5c0ad16478768\nauthor Kirjava <kirjavascript@users.noreply.github.com> 1736039111 +0000\ncommitter GitHub <noreply@github.com> 1736039111 +0000\n\nMerge pull request #120 from zohassadar/optimized_crunch\n\noptimized crunch with crash mode accommodated',
#     'verified_at': '2025-01-05T01:05:14Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/3e93562dd3308f087c262bcda0c76666dda40bab',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/3e93562dd3308f087c262bcda0c76666dda40bab',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/3e93562dd3308f087c262bcda0c76666dda40bab/comments',
#   'author': {'login': 'kirjavascript',
#    'id': 4498266,
#    'node_id': 'MDQ6VXNlcjQ0OTgyNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4498266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirjavascript',
#    'html_url': 'https://github.com/kirjavascript',
#    'followers_url': 'https://api.github.com/users/kirjavascript/followers',
#    'following_url': 'https://api.github.com/users/kirjavascript/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirjavascript/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirjavascript/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirjavascript/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirjavascript/orgs',
#    'repos_url': 'https://api.github.com/users/kirjavascript/repos',
#    'events_url': 'https://api.github.com/users/kirjavascript/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirjavascript/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '303a93fde5082e629be72e452992fd3b1ed3b464',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/303a93fde5082e629be72e452992fd3b1ed3b464',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/303a93fde5082e629be72e452992fd3b1ed3b464'},
#    {'sha': '2f04da63cd29ea5aae8ebc78b3e5c0ad16478768',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/2f04da63cd29ea5aae8ebc78b3e5c0ad16478768',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/2f04da63cd29ea5aae8ebc78b3e5c0ad16478768'}]},
#  {'sha': '303a93fde5082e629be72e452992fd3b1ed3b464',
#   'node_id': 'C_kwDOEXsaitoAKDMwM2E5M2ZkZTUwODJlNjI5YmU3MmU0NTI5OTJmZDNiMWVkM2I0NjQ',
#   'commit': {'author': {'name': 'Kirjava',
#     'email': 'kirjavascript@users.noreply.github.com',
#     'date': '2025-01-05T01:01:35Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-01-05T01:01:35Z'},
#    'message': 'Merge pull request #122 from zohassadar/harddrop_fix\n\nClear harddropBuffer before hard drop',
#    'tree': {'sha': '53b34c3dee750a84f535b9f33804b1e64d9025dd',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/53b34c3dee750a84f535b9f33804b1e64d9025dd'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/303a93fde5082e629be72e452992fd3b1ed3b464',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\ncCDMKXIDKP5XWt+nYpup\n=eA0Y\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 53b34c3dee750a84f535b9f33804b1e64d9025dd\nparent 3155e0358e06a66bb31a26eb91e0b05fef9dc8a4\nparent 5654a0b4de6630f757d12b1deef09954a6d62e0d\nauthor Kirjava <kirjavascript@users.noreply.github.com> 1736038895 +0000\ncommitter GitHub <noreply@github.com> 1736038895 +0000\n\nMerge pull request #122 from zohassadar/harddrop_fix\n\nClear harddropBuffer before hard drop',
#     'verified_at': '2025-01-05T01:01:38Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/303a93fde5082e629be72e452992fd3b1ed3b464',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/303a93fde5082e629be72e452992fd3b1ed3b464',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/303a93fde5082e629be72e452992fd3b1ed3b464/comments',
#   'author': {'login': 'kirjavascript',
#    'id': 4498266,
#    'node_id': 'MDQ6VXNlcjQ0OTgyNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4498266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirjavascript',
#    'html_url': 'https://github.com/kirjavascript',
#    'followers_url': 'https://api.github.com/users/kirjavascript/followers',
#    'following_url': 'https://api.github.com/users/kirjavascript/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirjavascript/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirjavascript/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirjavascript/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirjavascript/orgs',
#    'repos_url': 'https://api.github.com/users/kirjavascript/repos',
#    'events_url': 'https://api.github.com/users/kirjavascript/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirjavascript/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '3155e0358e06a66bb31a26eb91e0b05fef9dc8a4',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/3155e0358e06a66bb31a26eb91e0b05fef9dc8a4',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/3155e0358e06a66bb31a26eb91e0b05fef9dc8a4'},
#    {'sha': '5654a0b4de6630f757d12b1deef09954a6d62e0d',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/5654a0b4de6630f757d12b1deef09954a6d62e0d',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/5654a0b4de6630f757d12b1deef09954a6d62e0d'}]},
#  {'sha': '3155e0358e06a66bb31a26eb91e0b05fef9dc8a4',
#   'node_id': 'C_kwDOEXsaitoAKDMxNTVlMDM1OGUwNmE2NmJiMzFhMjZlYjkxZTBiMDVmZWY5ZGM4YTQ',
#   'commit': {'author': {'name': 'Kirjava',
#     'email': 'kirjavascript@users.noreply.github.com',
#     'date': '2025-01-05T00:59:14Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-01-05T00:59:14Z'},
#    'message': 'Merge pull request #123 from zohassadar/single_test_build_option\n\nrun single test',
#    'tree': {'sha': 'aef8e0de07f6e02c7d208d9e776f566d6b1e9b54',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/trees/aef8e0de07f6e02c7d208d9e776f566d6b1e9b54'},
#    'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/commits/3155e0358e06a66bb31a26eb91e0b05fef9dc8a4',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n3Tp1Lr0LQ8dBuLHeo2Ta\n=7fNy\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree aef8e0de07f6e02c7d208d9e776f566d6b1e9b54\nparent cb638563e3b6156e8dc5c9d6edcd37253e366172\nparent 9d8ce88759fdcf01efe640fada774d234174a97d\nauthor Kirjava <kirjavascript@users.noreply.github.com> 1736038754 +0000\ncommitter GitHub <noreply@github.com> 1736038754 +0000\n\nMerge pull request #123 from zohassadar/single_test_build_option\n\nrun single test',
#     'verified_at': '2025-01-05T00:59:17Z'}},
#   'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/3155e0358e06a66bb31a26eb91e0b05fef9dc8a4',
#   'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/3155e0358e06a66bb31a26eb91e0b05fef9dc8a4',
#   'comments_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/3155e0358e06a66bb31a26eb91e0b05fef9dc8a4/comments',
#   'author': {'login': 'kirjavascript',
#    'id': 4498266,
#    'node_id': 'MDQ6VXNlcjQ0OTgyNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4498266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirjavascript',
#    'html_url': 'https://github.com/kirjavascript',
#    'followers_url': 'https://api.github.com/users/kirjavascript/followers',
#    'following_url': 'https://api.github.com/users/kirjavascript/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirjavascript/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirjavascript/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirjavascript/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirjavascript/orgs',
#    'repos_url': 'https://api.github.com/users/kirjavascript/repos',
#    'events_url': 'https://api.github.com/users/kirjavascript/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirjavascript/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'cb638563e3b6156e8dc5c9d6edcd37253e366172',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/cb638563e3b6156e8dc5c9d6edcd37253e366172',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/cb638563e3b6156e8dc5c9d6edcd37253e366172'},
#    {'sha': '9d8ce88759fdcf01efe640fada774d234174a97d',
#     'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/commits/9d8ce88759fdcf01efe640fada774d234174a97d',
#     'html_url': 'https://github.com/kirjavascript/TetrisGYM/commit/9d8ce88759fdcf01efe640fada774d234174a97d'}]}]

# %%
repo_content1 = get_repository_contents("kirjavascript", 'TetrisGYM', path="README.md")

# %%
repo_content1
# Out:
# {'name': 'README.md',
#  'path': 'README.md',
#  'sha': '6e189300b931ee7569ec71d64634fe153f1047d5',
#  'size': 13358,
#  'url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/contents/README.md?ref=master',
#  'html_url': 'https://github.com/kirjavascript/TetrisGYM/blob/master/README.md',
#  'git_url': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/blobs/6e189300b931ee7569ec71d64634fe153f1047d5',
#  'download_url': 'https://raw.githubusercontent.com/kirjavascript/TetrisGYM/master/README.md',
#  'type': 'file',
#  'content': '\nbmQgd2hpY2ggYXJlIGZ ...
#  'encoding': 'base64',
#  '_links': {'self': 'https://api.github.com/repos/kirjavascript/TetrisGYM/contents/README.md?ref=master',
#   'git': 'https://api.github.com/repos/kirjavascript/TetrisGYM/git/blobs/6e189300b931ee7569ec71d64634fe153f1047d5',
#   'html': 'https://github.com/kirjavascript/TetrisGYM/blob/master/README.md'}}

# %% [markdown]
# #5.1 Examples data wrangling functions

# %%
clean_repos_data(repo_1)
# Out:
# Cleaned 5 repositories
#                    name                      full_name  \
# 0          -Nand2Tetris      pliniohavila/-Nand2Tetris
# 1  -nand2tetris-mynand-   hyfzero/-nand2tetris-mynand-
# 2    -nand2tetris-Part1  VEERESH069/-nand2tetris-Part1
# 3    -nand2tetris-Part1  Saksham091/-nand2tetris-Part1
# 4   -nand2tetris-Part1-    pawin46/-nand2tetris-Part1-
#
#                          description  language  stargazers_count  \
# 0                     No description  Assembly                 0
# 1  整理了我的作业（并制作了pdf版本）和nand2课程所需的所有资料  Assembly                 2
# 2                     No description  Assembly                 0
# 3                     No description  Assembly                 0
# 4                     No description  Assembly                 0
#
#                  created_at    owner_name
# 0 2024-04-24 16:01:19+00:00  pliniohavila
# 1 2021-01-21 04:33:53+00:00       hyfzero
# 2 2024-08-21 09:07:13+00:00    VEERESH069
# 3 2022-11-24 05:42:16+00:00    Saksham091
# 4 2024-08-27 09:16:51+00:00       pawin46

# %%
clean_commits_data(comm_1)
# Out:
# Cleaned 15 commits
#                                          sha    author_name  \
# 0   aad48e307c78d75fc6b4d05888c1529da4deeb9f     zohassadar
# 1   d4ffde98d5629ef4790ffa47699f7cb439631e8d     zohassadar
# 2   df937b12806b35332880d37057188d052d859260     zohassadar
# 3   d28bd744b5f784a3bacfcb0acf7ac5f4fcc85de2     zohassadar
# 4   961aa7aed01dc5a2d73f33d07b7ba488fa4202a5     zohassadar
# 5   a222aa463090986c3ff7f82b9213bec791055d34        Kirjava
# 6   d216a5e218f023b9f03d4affb4170f4ce0efefcb     zohassadar
# 7   9ad2faacc6cfd919782330659468028aea04533b        Kirjava
# 8   0983e24379a6195421f71da7f6a09adb9f325316     zohassadar
# 9   810a07f5cabc7cbbc646d24e104ab762ef7aa133  kirjavascript
# 10  b9abbe82899398efa84b4940107a87e55cab30de  kirjavascript
# 11  fd70e4d62eb6172fb5676717c5e3704869f8817d        Kirjava
# 12  3e93562dd3308f087c262bcda0c76666dda40bab        Kirjava
# 13  303a93fde5082e629be72e452992fd3b1ed3b464        Kirjava
# 14  3155e0358e06a66bb31a26eb91e0b05fef9dc8a4        Kirjava
#
#                               author_email               commit_date  \
# 0                     zohassadar@gmail.com 2025-06-20 21:06:07+00:00
# 1                     zohassadar@gmail.com 2025-03-26 22:22:44+00:00
# 2                     zohassadar@gmail.com 2025-02-01 19:49:33+00:00
# 3                     zohassadar@gmail.com 2025-01-30 22:47:24+00:00
# 4                     zohassadar@gmail.com 2025-01-30 20:05:48+00:00
# 5   kirjavascript@users.noreply.github.com 2025-01-05 19:39:31+00:00
# 6                     zohassadar@gmail.com 2025-01-05 19:18:26+00:00
# 7   kirjavascript@users.noreply.github.com 2025-01-05 02:25:56+00:00
# 8                     zohassadar@gmail.com 2025-01-05 02:12:46+00:00
# 9                       snkenjoi@gmail.com 2025-01-05 01:15:54+00:00
# 10                      snkenjoi@gmail.com 2025-01-05 01:06:47+00:00
# 11  kirjavascript@users.noreply.github.com 2025-01-05 01:05:22+00:00
# 12  kirjavascript@users.noreply.github.com 2025-01-05 01:05:11+00:00
# 13  kirjavascript@users.noreply.github.com 2025-01-05 01:01:35+00:00
# 14  kirjavascript@users.noreply.github.com 2025-01-05 00:59:14+00:00
#
#                                               message  \
# 0                     Add marathon modes 3 & 4 (#140)
# 1   Clean unused init bytes (#136)\n\nThese bytes ...
# 2   Add option to send additional build args to ca...
# 3   remove unneeded legacy tables (#132)\n\norient...
# 4   add harddrop.rs (#131)\n\nPut together to meas...
# 5   Merge pull request #129 from zohassadar/clear_...
# 6                       Clear crashState at game init
# 7   Merge pull request #127 from zohassadar/floor-...
# 8              sec in floor and adjust tspin constant
# 9                            revert sec in floor code
# 10                                   update changelog
# 11  Merge pull request #121 from zohassadar/crunch...
# 12  Merge pull request #120 from zohassadar/optimi...
# 13  Merge pull request #122 from zohassadar/harddr...
# 14  Merge pull request #123 from zohassadar/single...
#
#                                         message_clean
# 0                     Add marathon modes 3 & 4 (#140)
# 1   Clean unused init bytes (#136)  These bytes ar...
# 2   Add option to send additional build args to ca...
# 3   remove unneeded legacy tables (#132)  orientat...
# 4   add harddrop.rs (#131)  Put together to measur...
# 5   Merge pull request #129 from zohassadar/clear_...
# 6                       Clear crashState at game init
# 7   Merge pull request #127 from zohassadar/floor-...
# 8              sec in floor and adjust tspin constant
# 9                            revert sec in floor code
# 10                                   update changelog
# 11  Merge pull request #121 from zohassadar/crunch...
# 12  Merge pull request #120 from zohassadar/optimi...
# 13  Merge pull request #122 from zohassadar/harddr...
# 14  Merge pull request #123 from zohassadar/single...

# %% [markdown]
# #6.1. Test 1: Bad authentication

# %%
BASE_URL = "https://api.github.com"

TOKEN = "github_123456789"

HEADERS = {
    "Authorization": f"token {TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

response = requests.get("https://api.github.com/user", headers=HEADERS)
print(response.status_code, response.text)
# Out:
# 401 {"message":"Bad credentials","documentation_url":"https://docs.github.com/rest","status":"401"}

# %% [markdown]
# #6.2. Test 2: Rate limit checking

# %%
print("Remaining:", response.headers.get("X-RateLimit-Remaining"))
# Out:
# Remaining: 4993

# %% [markdown]
# #6.3 Test 3: Pagination

# %%
repos = paginate_repositories("tetris language:assembly", max_pages=2)
print(f"Total repos fetched: {len(repos)}")
print("Example repo:", repos[0]["full_name"])
# Out:
# Total repos fetched: 60
# Example repo: daniel-e/tetros

# %%
def paginate_repositories(query, max_pages=3, per_page=30):
    all_repos = []
    for page in range(1, max_pages + 1):
        params = {
            "q": query,
            "sort": "stars",
            "order": "desc",
            "per_page": per_page,
            "page": page
        }
        url = f"{BASE_URL}/search/repositories"
        response = make_api_request(url, params)
        if response and "items" in response:
            all_repos.extend(response["items"])
        else:
            break
    return all_repos

# %%
repos = paginate_repositories("tetris language:assembly", max_pages=2)
print(f"Total repos fetched: {len(repos)}")
print("Example repo:", repos[0]["full_name"])
# Out:
# Total repos fetched: 60
# Example repo: daniel-e/tetros
